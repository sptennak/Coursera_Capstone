# %% [markdown]
# # IBM Data Science Professional Certificate
# ## Applied Data Science Capstone
#
#
# # PART 1: Scraping Wikipedia page to obtain the table of postal codes
# https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M

# %%
from bs4 import BeautifulSoup
import requests

# %% [markdown]
# ## 1. Load page content

# %%
targetPage = r'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
source = requests.get(targetPage).text

# %% [markdown]
# ## 2. Parse HTML
# ### 2.1 Create soup

# %%
soup = BeautifulSoup(source, 'lxml')

# %% [markdown]
# ### 2.2 Extract table tag

# %%
tableStr = soup.find('table').prettify() # Returns HTML table tag as a string

# %% [markdown]
# ## 3. Convert HTML table to pandas dataframe
# http://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_html.html

# %%
import pandas as pd
df = pd.read_html(tableStr, match='str', header=0) # Returns a list of dataframes from tables tags in the input string. header=0 is denote the first row conatins the column lables.
postalcodes = df[0] # First dataframe in the list
postalcodes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 289 entries, 0 to 288
# Data columns (total 3 columns):
# Postcode         289 non-null object
# Borough          289 non-null object
# Neighbourhood    289 non-null object
# dtypes: object(3)
# memory usage: 6.9+ KB

# %%
postalcodes.head()
# Out:
#   Postcode           Borough     Neighbourhood
# 0      M1A      Not assigned      Not assigned
# 1      M2A      Not assigned      Not assigned
# 2      M3A        North York         Parkwoods
# 3      M4A        North York  Victoria Village
# 4      M5A  Downtown Toronto      Harbourfront

# %% [markdown]
# ## 4. Pre-Processing
# ### 4.1 Filter out the records that does not have  an assigned borough

# %%
postalcodes = postalcodes.loc[postalcodes.Borough!='Not assigned'].reset_index(drop=True)
postalcodes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 212 entries, 0 to 211
# Data columns (total 3 columns):
# Postcode         212 non-null object
# Borough          212 non-null object
# Neighbourhood    212 non-null object
# dtypes: object(3)
# memory usage: 5.0+ KB

# %%
postalcodes.head()
# Out:
#   Postcode           Borough     Neighbourhood
# 0      M3A        North York         Parkwoods
# 1      M4A        North York  Victoria Village
# 2      M5A  Downtown Toronto      Harbourfront
# 3      M5A  Downtown Toronto       Regent Park
# 4      M6A        North York  Lawrence Heights

# %% [markdown]
# ### 4.2 Collapse records with more than one neighborhood can exist in one postal code area

# %%
postalcodes = postalcodes.groupby(['Postcode','Borough'])['Neighbourhood'].apply(','.join).reset_index()
postalcodes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 3 columns):
# Postcode         103 non-null object
# Borough          103 non-null object
# Neighbourhood    103 non-null object
# dtypes: object(3)
# memory usage: 2.5+ KB

# %%
postalcodes.columns = ['PostalCode', 'Borough', 'Neighbourhood'] # Set column names
postalcodes.head()
# Out:
#   PostalCode      Borough                         Neighbourhood
# 0        M1B  Scarborough                         Rouge,Malvern
# 1        M1C  Scarborough  Highland Creek,Rouge Hill,Port Union
# 2        M1E  Scarborough       Guildwood,Morningside,West Hill
# 3        M1G  Scarborough                                Woburn
# 4        M1H  Scarborough                             Cedarbrae

# %% [markdown]
# ### 4.3 Assign Neighbourhood=Borough for the records with Neighbourhood='Not Assigned'

# %%
postalcodes.loc[postalcodes.Neighbourhood=='Not assigned'].reset_index(drop=True)
# Out:
#   PostalCode       Borough Neighbourhood
# 0        M7A  Queen's Park  Not assigned

# %%
postalcodes.loc[postalcodes.Neighbourhood=='Not assigned', 'Neighbourhood']=postalcodes.Borough

# %%
postalcodes.loc[postalcodes.Neighbourhood=='Not assigned'].reset_index(drop=True) # Should have no rows satisfying this condition excists
# Out:
# Empty DataFrame
# Columns: [PostalCode, Borough, Neighbourhood]
# Index: []

# %% [markdown]
# ## 5. Number of rows and columns in the dataframe

# %%
print('Number of Rows =', postalcodes.shape[0])
# Out:
# Number of Rows = 103

# %% [markdown]
# <hr>

# %% [markdown]
# # PART 2: Postal Code Map to Geographical Coordinates

# %%
#!conda install -c conda-forge geocoder --yes
import geocoder # import geocoder

# %%
# Function that convert postal code to coordicate (didn't work as expected)
# Source: Assignment description (https://www.coursera.org/learn/applied-data-science-capstone/peer/I1bDq/segmenting-and-clustering-neighborhoods-in-toronto/submit)

def PostalCodesToCoordinates(postalCode):
    # initialize your variable to None
    lat_lng_coords = None

    # loop until you get the coordinates
    while(lat_lng_coords is None):
      g = geocoder.google('{}, Toronto, Ontario'.format(postalCode))
      lat_lng_coords = g.latlng

    latitude = lat_lng_coords[0]
    longitude = lat_lng_coords[1]
    
    return latitude, longitude

# %% [markdown]
# ## 1. Load Geographical Coordinates Dataset

# %%
gc = pd.read_csv(r'https://cocl.us/Geospatial_data')
gc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 3 columns):
# Postal Code    103 non-null object
# Latitude       103 non-null float64
# Longitude      103 non-null float64
# dtypes: float64(2), object(1)
# memory usage: 2.5+ KB

# %%
gc.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %% [markdown]
# ## 2. Merge Geographical Coordinates Dataset with the Postal Code dataset

# %%
postalCodesCoord = postalcodes.merge(gc, left_on='PostalCode', right_on='Postal Code', how='left')
postalCodesCoord.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 103 entries, 0 to 102
# Data columns (total 6 columns):
# PostalCode       103 non-null object
# Borough          103 non-null object
# Neighbourhood    103 non-null object
# Postal Code      103 non-null object
# Latitude         103 non-null float64
# Longitude        103 non-null float64
# dtypes: float64(2), object(4)
# memory usage: 5.6+ KB

# %%
postalCodesCoord.head()
# Out:
#   PostalCode      Borough                         Neighbourhood Postal Code  \
# 0        M1B  Scarborough                         Rouge,Malvern         M1B
# 1        M1C  Scarborough  Highland Creek,Rouge Hill,Port Union         M1C
# 2        M1E  Scarborough       Guildwood,Morningside,West Hill         M1E
# 3        M1G  Scarborough                                Woburn         M1G
# 4        M1H  Scarborough                             Cedarbrae         M1H
#
#     Latitude  Longitude
# 0  43.806686 -79.194353
# 1  43.784535 -79.160497
# 2  43.763573 -79.188711
# 3  43.770992 -79.216917
# 4  43.773136 -79.239476

# %%
postalCode='M5G'
postalcodes.loc[postalcodes.PostalCode==postalCode]
# Out:
#    PostalCode           Borough       Neighbourhood
# 57        M5G  Downtown Toronto  Central Bay Street

# %% [markdown]
# # PART 3: Explore and Cluster Neighbourhood in Toronto

# %%
#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium

# %% [markdown]
# # 1. Create a map of Toronto using latitude and longitude values

# %%
latitude = 43.6487
longitude = -79.38544

neighborhoods = postalCodesCoord 

mapToronto = folium.Map(location=[latitude, longitude], zoom_start=10)

# %% [markdown]
# ## 2. Add markers to map

# %%
# Source: DP0701EN-3-3-2-Neighborhoods-New-York-py-v1.0.ipynb (https://www.coursera.org/learn/applied-data-science-capstone/ungradedLti/f0QY7/segmenting-and-clustering-neighborhoods-in-new-york-city)

for lat, lng, borough, neighborhood in zip(neighborhoods['Latitude'], neighborhoods['Longitude'], neighborhoods['Borough'], neighborhoods['Neighbourhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(mapToronto)  
    
mapToronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import json
import requests 
from pandas.io.json import json_normalize

# %%
# The code was removed by Watson Studio for sharing.

# %%
# The code was removed by Watson Studio for sharing.

# %% [markdown]
# ## Get request

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5c0de9421ed2194a781afb6e'},
#  'response': {'groups': [{'items': [{'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-50322b6ae4b09116a296568c-0',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/secretbar_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1d4941735',
#          'name': 'Speakeasy',
#          'pluralName': 'Speakeasies',
#          'primary': True,
#          'shortName': 'Speakeasy'}],
#        'id': '50322b6ae4b09116a296568c',
#        'location': {'address': '192 Adelaide St W',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'at Simcoe St.',
#         'distance': 88,
#         'formattedAddress': ['192 Adelaide St W (at Simcoe St.)',
#          'Toronto ON M5H 0A4',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64873430659662,
#           'lng': -79.38654117564838}],
#         'lat': 43.64873430659662,
#         'lng': -79.38654117564838,
#         'postalCode': 'M5H 0A4',
#         'state': 'ON'},
#        'name': 'Soho House Toronto',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4e31b74252b131dcebb08743-1',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'primary': True,
#          'shortName': 'Hotel'}],
#        'id': '4e31b74252b131dcebb08743',
#        'location': {'address': '188 University Ave.',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'at Adelaide St. W',
#         'distance': 101,
#         'formattedAddress': ['188 University Ave. (at Adelaide St. W)',
#          'Toronto ON M5H 0A3',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64912919417502,
#           'lng': -79.3865566853963}],
#         'lat': 43.64912919417502,
#         'lng': -79.3865566853963,
#         'postalCode': 'M5H 0A3',
#         'state': 'ON'},
#        'name': 'Shangri-La Toronto',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4ad69511f964a520e40721e3-2',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/steakhouse_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1cc941735',
#          'name': 'Steakhouse',
#          'pluralName': 'Steakhouses',
#          'primary': True,
#          'shortName': 'Steakhouse'}],
#        'id': '4ad69511f964a520e40721e3',
#        'location': {'address': '165 York St',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'btwn Richmond St. & Adelaide St.',
#         'distance': 170,
#         'formattedAddress': ['165 York St (btwn Richmond St. & Adelaide St.)',
#          'Toronto ON M5H 3R8',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.649937252985254,
#           'lng': -79.38419604942506}],
#         'lat': 43.649937252985254,
#         'lng': -79.38419604942506,
#         'postalCode': 'M5H 3R8',
#         'state': 'ON'},
#        'name': 'The Keg Steakhouse & Bar',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4ad4c061f964a520a9f720e3-3',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burrito_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d153941735',
#          'name': 'Burrito Place',
#          'pluralName': 'Burrito Places',
#          'primary': True,
#          'shortName': 'Burritos'}],
#        'id': '4ad4c061f964a520a9f720e3',
#        'location': {'address': '224 Adelaide St W',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'btwn Duncan & Simcoe',
#         'distance': 207,
#         'formattedAddress': ['224 Adelaide St W (btwn Duncan & Simcoe)',
#          'Toronto ON M5H 1W7',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.6484455955513,
#           'lng': -79.3879951787513}],
#         'lat': 43.6484455955513,
#         'lng': -79.3879951787513,
#         'postalCode': 'M5H 1W7',
#         'state': 'ON'},
#        'name': 'Burrito Boyz',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4ad4c062f964a520e5f720e3-4',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#           'suffix': '.png'},
#          'id': '5032792091d4c4b30a586d5c',
#          'name': 'Concert Hall',
#          'pluralName': 'Concert Halls',
#          'primary': True,
#          'shortName': 'Concert Hall'}],
#        'id': '4ad4c062f964a520e5f720e3',
#        'location': {'address': '145 Queen St. W',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'at University Ave.',
#         'distance': 222,
#         'formattedAddress': ['145 Queen St. W (at University Ave.)',
#          'Toronto ON M5H 4G1',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.65060862138792,
#           'lng': -79.38627956459021}],
#         'lat': 43.65060862138792,
#         'lng': -79.38627956459021,
#         'postalCode': 'M5H 4G1',
#         'state': 'ON'},
#        'name': 'Four Seasons Centre for the Performing Arts',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4ad4c061f964a520b0f720e3-5',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#           'suffix': '.png'},
#          'id': '5032792091d4c4b30a586d5c',
#          'name': 'Concert Hall',
#          'pluralName': 'Concert Halls',
#          'primary': True,
#          'shortName': 'Concert Hall'}],
#        'id': '4ad4c061f964a520b0f720e3',
#        'location': {'address': '60 Simcoe St',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'at King St W',
#         'distance': 239,
#         'formattedAddress': ['60 Simcoe St (at King St W)',
#          'Toronto ON M5J 2H5',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.6465886970634,
#           'lng': -79.38597899374354}],
#         'lat': 43.6465886970634,
#         'lng': -79.38597899374354,
#         'postalCode': 'M5J 2H5',
#         'state': 'ON'},
#        'name': 'Roy Thomson Hall',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '90484738'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4fccaa8fe4b05a98df3d9417-6',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'primary': True,
#          'shortName': 'Café'}],
#        'id': '4fccaa8fe4b05a98df3d9417',
#        'location': {'address': '150 King St. W',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'in the PATH',
#         'distance': 127,
#         'formattedAddress': ['150 King St. W (in the PATH)',
#          'Toronto ON M5H 4B6',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64788137014028,
#           'lng': -79.38433152836829}],
#         'lat': 43.64788137014028,
#         'lng': -79.38433152836829,
#         'postalCode': 'M5H 4B6',
#         'state': 'ON'},
#        'name': 'Sam James Coffee Bar (SJCB)',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5321f4d9e4b07946702e6e08-7',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mediterranean_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1c0941735',
#          'name': 'Mediterranean Restaurant',
#          'pluralName': 'Mediterranean Restaurants',
#          'primary': True,
#          'shortName': 'Mediterranean'}],
#        'id': '5321f4d9e4b07946702e6e08',
#        'location': {'address': '11 Duncan St. 1st Floor',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'distance': 265,
#         'formattedAddress': ['11 Duncan St. 1st Floor',
#          'Toronto ON M5V 3M2',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.647615054171766,
#           'lng': -79.3883810317138}],
#         'lat': 43.647615054171766,
#         'lng': -79.3883810317138,
#         'postalCode': 'M5V 3M2',
#         'state': 'ON'},
#        'name': 'Byblos Toronto',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5578720f498ee3b165b1f32b-8',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d16c941735',
#          'name': 'Burger Joint',
#          'pluralName': 'Burger Joints',
#          'primary': True,
#          'shortName': 'Burgers'}],
#        'id': '5578720f498ee3b165b1f32b',
#        'location': {'address': '212 Adelaide Street West',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'distance': 157,
#         'formattedAddress': ['212 Adelaide Street West',
#          'Toronto ON M5H 1W7',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.648476440165176,
#           'lng': -79.38737257506915}],
#         'lat': 43.648476440165176,
#         'lng': -79.38737257506915,
#         'postalCode': 'M5H 1W7',
#         'state': 'ON'},
#        'name': "The Burger's Priest",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5462ac56498e128ccafe8fea-9',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'primary': True,
#          'shortName': 'Pizza'}],
#        'id': '5462ac56498e128ccafe8fea',
#        'location': {'address': '155 University Ave',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'at Pearl St',
#         'distance': 48,
#         'formattedAddress': ['155 University Ave (at Pearl St)',
#          'Toronto ON M5H 3B7',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64833354686235,
#           'lng': -79.38511050184168}],
#         'lat': 43.64833354686235,
#         'lng': -79.38511050184168,
#         'postalCode': 'M5H 3B7',
#         'state': 'ON'},
#        'name': 'Pizzeria Libretto',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-529612de11d2ab526191ccc9-10',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d149941735',
#          'name': 'Thai Restaurant',
#          'pluralName': 'Thai Restaurants',
#          'primary': True,
#          'shortName': 'Thai'}],
#        'id': '529612de11d2ab526191ccc9',
#        'location': {'address': '18 Duncan St',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'Adelaide and Duncan',
#         'distance': 267,
#         'formattedAddress': ['18 Duncan St (Adelaide and Duncan)',
#          'Toronto ON M5H 3G6',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64792310735613,
#           'lng': -79.38857932631602}],
#         'lat': 43.64792310735613,
#         'lng': -79.38857932631602,
#         'neighborhood': 'Entertainment District',
#         'postalCode': 'M5H 3G6',
#         'state': 'ON'},
#        'name': 'Pai',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-509bb871e4b09c7ac93f6642-11',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1d2941735',
#          'name': 'Sushi Restaurant',
#          'pluralName': 'Sushi Restaurants',
#          'primary': True,
#          'shortName': 'Sushi'}],
#        'id': '509bb871e4b09c7ac93f6642',
#        'location': {'address': '222 Richmond St W',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'distance': 240,
#         'formattedAddress': ['222 Richmond St W',
#          'Toronto ON M5V 1W4',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64968685893743,
#           'lng': -79.38809001547467}],
#         'lat': 43.64968685893743,
#         'lng': -79.38809001547467,
#         'postalCode': 'M5V 1W4',
#         'state': 'ON'},
#        'name': 'JaBistro',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '148995303'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-52ec621e498ec68fa15ee922-12',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/argentinian_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d16b941735',
#          'name': 'Brazilian Restaurant',
#          'pluralName': 'Brazilian Restaurants',
#          'primary': True,
#          'shortName': 'Brazilian'}],
#        'id': '52ec621e498ec68fa15ee922',
#        'location': {'address': '230 Adelaide St W #2',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'at Duncan St.',
#         'distance': 222,
#         'formattedAddress': ['230 Adelaide St W #2 (at Duncan St.)',
#          'Toronto ON M5H 3H1',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64833259480477,
#           'lng': -79.3881514766071}],
#         'lat': 43.64833259480477,
#         'lng': -79.3881514766071,
#         'postalCode': 'M5H 3H1',
#         'state': 'ON'},
#        'name': 'Copacabana Grilled Brazilian',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4ad4c062f964a520bbf720e3-13',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/performingarts_theater_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d137941735',
#          'name': 'Theater',
#          'pluralName': 'Theaters',
#          'primary': True,
#          'shortName': 'Theater'}],
#        'id': '4ad4c062f964a520bbf720e3',
#        'location': {'address': '260 King St W',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'at Duncan St',
#         'distance': 241,
#         'formattedAddress': ['260 King St W (at Duncan St)',
#          'Toronto ON M5V 1H9',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.6470880873779,
#           'lng': -79.38744381256471}],
#         'lat': 43.6470880873779,
#         'lng': -79.38744381256471,
#         'postalCode': 'M5V 1H9',
#         'state': 'ON'},
#        'name': 'Royal Alexandra Theatre',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '32823702'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b6b4340f964a520c9fc2be3-14',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'primary': True,
#          'shortName': 'Coffee Shop'}],
#        'id': '4b6b4340f964a520c9fc2be3',
#        'location': {'address': '55 University Ave,Unit #3',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'at Wellington St. W',
#         'distance': 212,
#         'formattedAddress': ['55 University Ave,Unit #3 (at Wellington St. W)',
#          'Toronto ON M5J 2H7',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.646935797838935,
#           'lng': -79.38442766632808}],
#         'lat': 43.646935797838935,
#         'lng': -79.38442766632808,
#         'postalCode': 'M5J 2H7',
#         'state': 'ON'},
#        'name': 'Starbucks',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-505125b2e4b0253ca4e47351-15',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/ramen_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1d1941735',
#          'name': 'Noodle House',
#          'pluralName': 'Noodle Houses',
#          'primary': True,
#          'shortName': 'Noodles'}],
#        'id': '505125b2e4b0253ca4e47351',
#        'location': {'address': '190 University Ave',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'btwn Richmond & Adelaide St W',
#         'distance': 96,
#         'formattedAddress': ['190 University Ave (btwn Richmond & Adelaide St W)',
#          'Toronto ON M5H 0A3',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.6493658716176,
#           'lng': -79.38621652451032}],
#         'lat': 43.6493658716176,
#         'lng': -79.38621652451032,
#         'postalCode': 'M5H 0A3',
#         'state': 'ON'},
#        'name': 'Momofuku Noodle Bar',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '167827980'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4e048b98315168be7fd7ee4d-16',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/greek_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d10e941735',
#          'name': 'Greek Restaurant',
#          'pluralName': 'Greek Restaurants',
#          'primary': True,
#          'shortName': 'Greek'}],
#        'id': '4e048b98315168be7fd7ee4d',
#        'location': {'address': '133 Richmond St. W',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'at York St.',
#         'distance': 195,
#         'formattedAddress': ['133 Richmond St. W (at York St.)',
#          'Toronto ON M5H 2L3',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.65032912559998,
#           'lng': -79.38453301297716}],
#         'lat': 43.65032912559998,
#         'lng': -79.38453301297716,
#         'postalCode': 'M5H 2L3',
#         'state': 'ON'},
#        'name': 'Estiatorio Volos',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '75877391'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-50468014e4b01c18bb731df8-17',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d142941735',
#          'name': 'Asian Restaurant',
#          'pluralName': 'Asian Restaurants',
#          'primary': True,
#          'shortName': 'Asian'}],
#        'id': '50468014e4b01c18bb731df8',
#        'location': {'address': '188 University Ave.',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'distance': 47,
#         'formattedAddress': ['188 University Ave.',
#          'Toronto ON M5H 0A3',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.649022736761516,
#           'lng': -79.38582635521233}],
#         'lat': 43.649022736761516,
#         'lng': -79.38582635521233,
#         'postalCode': 'M5H 0A3',
#         'state': 'ON'},
#        'name': 'Bosk at Shangri-La',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4bd8cde92e6f0f47dcb20808-18',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/steakhouse_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1cc941735',
#          'name': 'Steakhouse',
#          'pluralName': 'Steakhouses',
#          'primary': True,
#          'shortName': 'Steakhouse'}],
#        'id': '4bd8cde92e6f0f47dcb20808',
#        'location': {'address': '120 Adelaide St. W',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'at York St',
#         'distance': 221,
#         'formattedAddress': ['120 Adelaide St. W (at York St)',
#          'Toronto ON M5H 1T1',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.649504756476944,
#           'lng': -79.38291850488223}],
#         'lat': 43.649504756476944,
#         'lng': -79.38291850488223,
#         'postalCode': 'M5H 1T1',
#         'state': 'ON'},
#        'name': "Hy's Steakhouse",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5b6c842bc36588002c80a934-19',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'primary': True,
#          'shortName': 'Café'}],
#        'id': '5b6c842bc36588002c80a934',
#        'location': {'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'distance': 21,
#         'formattedAddress': ['Toronto ON M5H 4E7', 'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.648811,
#           'lng': -79.385217}],
#         'lat': 43.648811,
#         'lng': -79.385217,
#         'postalCode': 'M5H 4E7',
#         'state': 'ON'},
#        'name': 'Cafe Landwer',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-559a8f5a498e31f945041245-20',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'primary': True,
#          'shortName': 'Café'}],
#        'id': '559a8f5a498e31f945041245',
#        'location': {'address': '100 King St W',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'btwn Bay & York st',
#         'distance': 260,
#         'formattedAddress': ['100 King St W (btwn Bay & York st)',
#          'Toronto ON M5X 1C1',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64830873804684,
#           'lng': -79.38225333898805}],
#         'lat': 43.64830873804684,
#         'lng': -79.38225333898805,
#         'postalCode': 'M5X 1C1',
#         'state': 'ON'},
#        'name': 'Maman',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4afa1f33f964a520e91622e3-21',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d111941735',
#          'name': 'Japanese Restaurant',
#          'pluralName': 'Japanese Restaurants',
#          'primary': True,
#          'shortName': 'Japanese'}],
#        'id': '4afa1f33f964a520e91622e3',
#        'location': {'address': '100 Simcoe St.',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'at Pearl St.',
#         'distance': 84,
#         'formattedAddress': ['100 Simcoe St. (at Pearl St.)',
#          'Toronto ON',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64851365544565,
#           'lng': -79.38645657820041}],
#         'lat': 43.64851365544565,
#         'lng': -79.38645657820041,
#         'state': 'ON'},
#        'name': 'Fune Japanese Restaurant',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-59603f86112c6c70931c9401-22',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/gastropub_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d155941735',
#          'name': 'Gastropub',
#          'pluralName': 'Gastropubs',
#          'primary': True,
#          'shortName': 'Gastropub'}],
#        'id': '59603f86112c6c70931c9401',
#        'location': {'address': '100 King St W',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'distance': 273,
#         'formattedAddress': ['100 King St W', 'Toronto ON', 'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.648475974183,
#           'lng': -79.38205778358744}],
#         'lat': 43.648475974183,
#         'lng': -79.38205778358744,
#         'state': 'ON'},
#        'name': 'King Taps',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4a9d0a53f964a520d23720e3-23',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'primary': True,
#          'shortName': 'Hotel'}],
#        'id': '4a9d0a53f964a520d23720e3',
#        'location': {'address': '145 Richmond Street West',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'at University Ave',
#         'distance': 128,
#         'formattedAddress': ['145 Richmond Street West (at University Ave)',
#          'Toronto ON M5H 2L2',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64985232228859,
#           'lng': -79.38557624816895}],
#         'lat': 43.64985232228859,
#         'lng': -79.38557624816895,
#         'postalCode': 'M5H 2L2',
#         'state': 'ON'},
#        'name': 'Hilton Toronto',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4ea43642be7ba4918efc5afa-24',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d175941735',
#          'name': 'Gym / Fitness Center',
#          'pluralName': 'Gyms or Fitness Centers',
#          'primary': True,
#          'shortName': 'Gym / Fitness'}],
#        'id': '4ea43642be7ba4918efc5afa',
#        'location': {'address': '1 First Canadian Place',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'distance': 290,
#         'formattedAddress': ['1 First Canadian Place',
#          'Toronto ON M5X 1C8',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64927944291712,
#           'lng': -79.38192123284551}],
#         'lat': 43.64927944291712,
#         'lng': -79.38192123284551,
#         'postalCode': 'M5X 1C8',
#         'state': 'ON'},
#        'name': 'Adelaide Club Toronto',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4d2b615e342d6dcb2b8115cb-25',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'primary': True,
#          'shortName': 'Bar'}],
#        'id': '4d2b615e342d6dcb2b8115cb',
#        'location': {'address': '150 King St. W.',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'at York St.',
#         'distance': 158,
#         'formattedAddress': ['150 King St. W. (at York St.)',
#          'Toronto ON M5H 2B6',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.647923453007955,
#           'lng': -79.38378948070567}],
#         'lat': 43.647923453007955,
#         'lng': -79.38378948070567,
#         'postalCode': 'M5H 2B6',
#         'state': 'ON'},
#        'name': 'Earls Kitchen & Bar',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-50ca02c5245f2d4aa8c2c53d-26',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/steakhouse_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1cc941735',
#          'name': 'Steakhouse',
#          'pluralName': 'Steakhouses',
#          'primary': True,
#          'shortName': 'Steakhouse'}],
#        'id': '50ca02c5245f2d4aa8c2c53d',
#        'location': {'address': '145 Richmond Street, Hilton Toronto',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'at University Ave.',
#         'distance': 137,
#         'formattedAddress': ['145 Richmond Street, Hilton Toronto (at University Ave.)',
#          'Toronto ON M5H 2L2',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.6499174,
#           'lng': -79.3857238}],
#         'lat': 43.6499174,
#         'lng': -79.3857238,
#         'postalCode': 'M5H 2L2',
#         'state': 'ON'},
#        'name': "Ruth's Chris Steak House",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b7ed424f964a5208a0230e3-27',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/tobacco_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d123951735',
#          'name': 'Smoke Shop',
#          'pluralName': 'Smoke Shops',
#          'primary': True,
#          'shortName': 'Smoke Shop'}],
#        'id': '4b7ed424f964a5208a0230e3',
#        'location': {'address': '241 Queen St. W',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'at St. Patrick St.',
#         'distance': 311,
#         'formattedAddress': ['241 Queen St. W (at St. Patrick St.)',
#          'Toronto ON M5V 1Z4',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.650386666114635,
#           'lng': -79.38852348995324}],
#         'lat': 43.650386666114635,
#         'lng': -79.38852348995324,
#         'postalCode': 'M5V 1Z4',
#         'state': 'ON'},
#        'name': 'Friendly Stranger - Cannabis Culture Shop',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '42625936'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4ac4e289f964a520699f20e3-28',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1d2941735',
#          'name': 'Sushi Restaurant',
#          'pluralName': 'Sushi Restaurants',
#          'primary': True,
#          'shortName': 'Sushi'}],
#        'id': '4ac4e289f964a520699f20e3',
#        'location': {'address': '236 Adelaide St. W',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'at Duncan St.',
#         'distance': 237,
#         'formattedAddress': ['236 Adelaide St. W (at Duncan St.)',
#          'Toronto ON M5H 1W7',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.6483011115534,
#           'lng': -79.3883359381972}],
#         'lat': 43.6483011115534,
#         'lng': -79.3883359381972,
#         'postalCode': 'M5H 1W7',
#         'state': 'ON'},
#        'name': 'Yuzu No Hana',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5227fd9d7e48b6c9c707f4fa-29',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'primary': True,
#          'shortName': 'Café'}],
#        'id': '5227fd9d7e48b6c9c707f4fa',
#        'location': {'address': '150 King Street West',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'The PATH @ King & University',
#         'distance': 146,
#         'formattedAddress': ['150 King Street West (The PATH @ King & University)',
#          'Toronto ON M5H 1J9',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.647595917807365,
#           'lng': -79.38641938975012}],
#         'lat': 43.647595917807365,
#         'lng': -79.38641938975012,
#         'postalCode': 'M5H 1J9',
#         'state': 'ON'},
#        'name': 'Astarté Fresh Yogurt Bar',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5a32970da42362290203a9d6-30',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d120951735',
#          'name': 'Food Court',
#          'pluralName': 'Food Courts',
#          'primary': True,
#          'shortName': 'Food Court'}],
#        'id': '5a32970da42362290203a9d6',
#        'location': {'address': '111 Richmond St W',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'btwn York & Bay St',
#         'distance': 265,
#         'formattedAddress': ['111 Richmond St W (btwn York & Bay St)',
#          'Toronto ON M5H 2G4',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.650578865093934,
#           'lng': -79.3834119303614}],
#         'lat': 43.650578865093934,
#         'lng': -79.3834119303614,
#         'neighborhood': 'Financial District',
#         'postalCode': 'M5H 2G4',
#         'state': 'ON'},
#        'name': "Assembly Chef's Hall",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-53856fa411d2061fc84a3d0a-31',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d121941735',
#          'name': 'Lounge',
#          'pluralName': 'Lounges',
#          'primary': True,
#          'shortName': 'Lounge'}],
#        'id': '53856fa411d2061fc84a3d0a',
#        'location': {'address': '188 University Ave.',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'distance': 102,
#         'formattedAddress': ['188 University Ave.',
#          'Toronto ON M5H 0A3',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64915499986854,
#           'lng': -79.38654574367817}],
#         'lat': 43.64915499986854,
#         'lng': -79.38654574367817,
#         'postalCode': 'M5H 0A3',
#         'state': 'ON'},
#        'name': 'Lobby Lounge at the Shangri-La Toronto',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5a5a59c5a423620ec1dafd41-32',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'primary': True,
#          'shortName': 'Pizza'}],
#        'id': '5a5a59c5a423620ec1dafd41',
#        'location': {'address': '170 University Ave',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'Adelaide St W',
#         'distance': 35,
#         'formattedAddress': ['170 University Ave (Adelaide St W)',
#          'Toronto ON M5H 3B3',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.648651,
#           'lng': -79.385874}],
#         'lat': 43.648651,
#         'lng': -79.385874,
#         'postalCode': 'M5H 3B3',
#         'state': 'ON'},
#        'name': 'Pi Co.',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5aff06ca6e4650002cc6286b-33',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1d3941735',
#          'name': 'Vegetarian / Vegan Restaurant',
#          'pluralName': 'Vegetarian / Vegan Restaurants',
#          'primary': True,
#          'shortName': 'Vegetarian / Vegan'}],
#        'id': '5aff06ca6e4650002cc6286b',
#        'location': {'address': '133 Richmond St W',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'distance': 174,
#         'formattedAddress': ['133 Richmond St W',
#          'Toronto ON M5H 2L2',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.650252483069295,
#           'lng': -79.38515575620075}],
#         'lat': 43.650252483069295,
#         'lng': -79.38515575620075,
#         'postalCode': 'M5H 2L2',
#         'state': 'ON'},
#        'name': 'Rosalinda',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b6609b3f964a5200c102be3-34',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1f6931735',
#          'name': 'General Travel',
#          'pluralName': 'General Travel',
#          'primary': True,
#          'shortName': 'Travel'}],
#        'id': '4b6609b3f964a5200c102be3',
#        'location': {'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'btwn John St., Yonge St., Elm St. and Front St.',
#         'distance': 234,
#         'formattedAddress': ['All Around Downtown Toronto (btwn John St., Yonge St., Elm St. and Front St.)',
#          'Toronto ON',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64990340698978,
#           'lng': -79.3830527039004}],
#         'lat': 43.64990340698978,
#         'lng': -79.3830527039004,
#         'state': 'ON'},
#        'name': 'Toronto PATH System',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5057b3d1e4b0e54029a4acc8-35',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/steakhouse_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1cc941735',
#          'name': 'Steakhouse',
#          'pluralName': 'Steakhouses',
#          'primary': True,
#          'shortName': 'Steakhouse'}],
#        'id': '5057b3d1e4b0e54029a4acc8',
#        'location': {'address': '100 Simcoe St',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'at Adelaide St',
#         'distance': 86,
#         'formattedAddress': ['100 Simcoe St (at Adelaide St)',
#          'Toronto ON M5H 3G2',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64826881661747,
#           'lng': -79.38632821234134}],
#         'lat': 43.64826881661747,
#         'lng': -79.38632821234134,
#         'postalCode': 'M5H 3G2',
#         'state': 'ON'},
#        'name': "Michael's on Simcoe",
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '80039571'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4ad4c05df964a52059f620e3-36',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'primary': True,
#          'shortName': 'Restaurant'}],
#        'id': '4ad4c05df964a52059f620e3',
#        'location': {'address': '66 Wellington St West',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'at Bay Street',
#         'distance': 359,
#         'formattedAddress': ['66 Wellington St West (at Bay Street)',
#          'Toronto ON M5K 1H6',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.647452066183476,
#           'lng': -79.38132001815676}],
#         'lat': 43.647452066183476,
#         'lng': -79.38132001815676,
#         'postalCode': 'M5K 1H6',
#         'state': 'ON'},
#        'name': 'Canoe',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '40552945'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-56df0683498e7d0423e91b5b-37',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/salad_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1bd941735',
#          'name': 'Salad Place',
#          'pluralName': 'Salad Places',
#          'primary': True,
#          'shortName': 'Salad'}],
#        'id': '56df0683498e7d0423e91b5b',
#        'location': {'cc': 'CA',
#         'country': 'Canada',
#         'distance': 264,
#         'formattedAddress': ['Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64835708519922,
#           'lng': -79.38219241858727}],
#         'lat': 43.64835708519922,
#         'lng': -79.38219241858727},
#        'name': 'iQ Food Co. (First Canadian Place)',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-55fc571f498ec35023360858-38',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d14e941735',
#          'name': 'American Restaurant',
#          'pluralName': 'American Restaurants',
#          'primary': True,
#          'shortName': 'American'}],
#        'id': '55fc571f498ec35023360858',
#        'location': {'address': '77 Adelaide St W',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'btwn Bay & York St',
#         'distance': 318,
#         'formattedAddress': ['77 Adelaide St W (btwn Bay & York St)',
#          'Toronto ON M5X 1C1',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.6495520142626,
#           'lng': -79.38167072512041}],
#         'lat': 43.6495520142626,
#         'lng': -79.38167072512041,
#         'postalCode': 'M5X 1C1',
#         'state': 'ON'},
#        'name': 'Cactus Club Cafe',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4c3a8e78be4620a1c6180b13-39',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/breakfast_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d143941735',
#          'name': 'Breakfast Spot',
#          'pluralName': 'Breakfast Spots',
#          'primary': True,
#          'shortName': 'Breakfast'}],
#        'id': '4c3a8e78be4620a1c6180b13',
#        'location': {'address': '145 Richmond Street West',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'distance': 187,
# ...
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d14e941735',
#          'name': 'American Restaurant',
#          'pluralName': 'American Restaurants',
#          'primary': True,
#          'shortName': 'American'}],
#        'id': '4d3997e1687ca35dbd0081c4',
#        'location': {'address': '372 Bay St',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'at Richmond St.',
#         'distance': 424,
#         'formattedAddress': ['372 Bay St (at Richmond St.)',
#          'Toronto ON M5H 1W2',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.65098801064232,
#           'lng': -79.38122513218154}],
#         'lat': 43.65098801064232,
#         'lng': -79.38122513218154,
#         'postalCode': 'M5H 1W2',
#         'state': 'ON'},
#        'name': 'The Gabardine',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4ad639a0f964a520d90521e3-88',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d11b941735',
#          'name': 'Pub',
#          'pluralName': 'Pubs',
#          'primary': True,
#          'shortName': 'Pub'}],
#        'id': '4ad639a0f964a520d90521e3',
#        'location': {'address': '14 Duncan Street',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'at King',
#         'distance': 278,
#         'formattedAddress': ['14 Duncan Street (at King)',
#          'Toronto ON M5H 3G8',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64764566165518,
#           'lng': -79.38857157360519}],
#         'lat': 43.64764566165518,
#         'lng': -79.38857157360519,
#         'postalCode': 'M5H 3G8',
#         'state': 'ON'},
#        'name': "Grace O'Malley's",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4ee117150cd686aafce847f4-89',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'id': '52e81612bcbc57f1066b79f9',
#          'name': 'Modern European Restaurant',
#          'pluralName': 'Modern European Restaurants',
#          'primary': True,
#          'shortName': 'Modern European'}],
#        'id': '4ee117150cd686aafce847f4',
#        'location': {'address': '225 Richmond St W., Suite 501b',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'distance': 318,
#         'formattedAddress': ['225 Richmond St W., Suite 501b',
#          'Toronto ON M5V 1W2',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.649249809335,
#           'lng': -79.38931975675418}],
#         'lat': 43.649249809335,
#         'lng': -79.38931975675418,
#         'postalCode': 'M5V 1W2',
#         'state': 'ON'},
#        'name': 'The Fifth & Terrace',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '401666972'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4ae603a5f964a52010a421e3-90',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/sportsbar_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d11d941735',
#          'name': 'Sports Bar',
#          'pluralName': 'Sports Bars',
#          'primary': True,
#          'shortName': 'Sports Bar'}],
#        'id': '4ae603a5f964a52010a421e3',
#        'location': {'address': '146 Front St W',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'btwn Simcoe & York',
#         'distance': 398,
#         'formattedAddress': ['146 Front St W (btwn Simcoe & York)',
#          'Toronto ON M5J 1G2',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64528061938072,
#           'lng': -79.38396600831251}],
#         'lat': 43.64528061938072,
#         'lng': -79.38396600831251,
#         'postalCode': 'M5J 1G2',
#         'state': 'ON'},
#        'name': 'Loose Moose Tap & Grill',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-538bf897498e8301b31e1e65-91',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'primary': True,
#          'shortName': 'Bar'}],
#        'id': '538bf897498e8301b31e1e65',
#        'location': {'address': '250 Adelaide Street West',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'Duncan Street',
#         'distance': 291,
#         'formattedAddress': ['250 Adelaide Street West (Duncan Street)',
#          'Toronto ON M5H 1X6',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64825063999569,
#           'lng': -79.38900157428692}],
#         'lat': 43.64825063999569,
#         'lng': -79.38900157428692,
#         'postalCode': 'M5H 1X6',
#         'state': 'ON'},
#        'name': 'The Porch',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-57be1ded498edab44ddf8725-92',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d16e941735',
#          'name': 'Fast Food Restaurant',
#          'pluralName': 'Fast Food Restaurants',
#          'primary': True,
#          'shortName': 'Fast Food'}],
#        'id': '57be1ded498edab44ddf8725',
#        'location': {'address': '8 Mercer St',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'John St',
#         'distance': 446,
#         'formattedAddress': ['8 Mercer St (John St)',
#          'Toronto ON M5V 3W2',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64603006633529,
#           'lng': -79.3895772055033}],
#         'lat': 43.64603006633529,
#         'lng': -79.3895772055033,
#         'postalCode': 'M5V 3W2',
#         'state': 'ON'},
#        'name': 'A&W',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4c649c71073795215b7dd348-93',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'primary': True,
#          'shortName': 'Restaurant'}],
#        'id': '4c649c71073795215b7dd348',
#        'location': {'address': '330 King St West',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'TIFF Bell Lightbox',
#         'distance': 428,
#         'formattedAddress': ['330 King St West (TIFF Bell Lightbox)',
#          'Toronto ON M5V 3X5',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64649231938484,
#           'lng': -79.3897916366583}],
#         'lat': 43.64649231938484,
#         'lng': -79.3897916366583,
#         'postalCode': 'M5V 3X5',
#         'state': 'ON'},
#        'name': 'Luma',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '41473026'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-59f784dd28122f14f9d5d63d-94',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'primary': True,
#          'shortName': 'Coffee Shop'}],
#        'id': '59f784dd28122f14f9d5d63d',
#        'location': {'address': '245 Queen Street West',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'distance': 319,
#         'formattedAddress': ['245 Queen Street West',
#          'Toronto ON M5V 1Z4',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.65036434800487,
#           'lng': -79.38866907575726}],
#         'lat': 43.65036434800487,
#         'lng': -79.38866907575726,
#         'postalCode': 'M5V 1Z4',
#         'state': 'ON'},
#        'name': 'HotBlack Coffee',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '463001529'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b193b23f964a520a4d923e3-95',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d163941735',
#          'name': 'Park',
#          'pluralName': 'Parks',
#          'primary': True,
#          'shortName': 'Park'}],
#        'id': '4b193b23f964a520a4d923e3',
#        'location': {'address': '225 King St. W',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'btwn Simcoe And John St.',
#         'distance': 283,
#         'formattedAddress': ['225 King St. W (btwn Simcoe And John St.)',
#          'Toronto ON M5V 3C6',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.646743128025875,
#           'lng': -79.38770055770874}],
#         'lat': 43.646743128025875,
#         'lng': -79.38770055770874,
#         'postalCode': 'M5V 3C6',
#         'state': 'ON'},
#        'name': 'David Pecaut Square',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-54065e3e498e13320be9ec0d-96',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'primary': True,
#          'shortName': 'Restaurant'}],
#        'id': '54065e3e498e13320be9ec0d',
#        'location': {'address': '304 Richmond Street West',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'John St. & Richmond St. West',
#         'distance': 495,
#         'formattedAddress': ['304 Richmond Street West (John St. & Richmond St. West)',
#          'Toronto ON M5V 1X2',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64900182395426,
#           'lng': -79.39157569644912}],
#         'lat': 43.64900182395426,
#         'lng': -79.39157569644912,
#         'postalCode': 'M5V 1X2',
#         'state': 'ON'},
#        'name': 'Thoroughbred Food & Drink',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '95724765'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-55a63131498e114c3c6d2cd5-97',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d146941735',
#          'name': 'Deli / Bodega',
#          'pluralName': 'Delis / Bodegas',
#          'primary': True,
#          'shortName': 'Deli / Bodega'}],
#        'id': '55a63131498e114c3c6d2cd5',
#        'location': {'address': 'TD Centre',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'distance': 393,
#         'formattedAddress': ['TD Centre', 'Toronto ON M5A 0A1', 'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64716011126396,
#           'lng': -79.38104402548048}],
#         'lat': 43.64716011126396,
#         'lng': -79.38104402548048,
#         'postalCode': 'M5A 0A1',
#         'state': 'ON'},
#        'name': 'McEwan Foods',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4ab83d73f964a520ad7c20e3-98',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d10c941735',
#          'name': 'French Restaurant',
#          'pluralName': 'French Restaurants',
#          'primary': True,
#          'shortName': 'French'}],
#        'id': '4ab83d73f964a520ad7c20e3',
#        'location': {'address': '246 Queen St W',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'at John St',
#         'distance': 464,
#         'formattedAddress': ['246 Queen St W (at John St)',
#          'Toronto ON M5V 1Z7',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.64994045003638,
#           'lng': -79.3909491448013}],
#         'lat': 43.64994045003638,
#         'lng': -79.3909491448013,
#         'postalCode': 'M5V 1Z7',
#         'state': 'ON'},
#        'name': 'Café Crêpe',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-595d4380c876c841c08f1959-99',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/souvlaki_',
#           'suffix': '.png'},
#          'id': '52e81612bcbc57f1066b79f3',
#          'name': 'Souvlaki Shop',
#          'pluralName': 'Souvlaki Shops',
#          'primary': True,
#          'shortName': 'Souvlaki'}],
#        'id': '595d4380c876c841c08f1959',
#        'location': {'address': '155 John St.',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'Queen St. & John St.',
#         'distance': 480,
#         'formattedAddress': ['155 John St. (Queen St. & John St.)',
#          'Toronto ON M5T 1X3',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.6500639687058,
#           'lng': -79.39110371201055}],
#         'lat': 43.6500639687058,
#         'lng': -79.39110371201055,
#         'postalCode': 'M5T 1X3',
#         'state': 'ON'},
#        'name': 'Omg! Oh My Gyro!',
#        'photos': {'count': 0, 'groups': []}}}],
#     'name': 'recommended',
#     'type': 'Recommended Places'}],
#   'headerFullLocation': 'Entertainment District, Toronto',
#   'headerLocation': 'Entertainment District',
#   'headerLocationGranularity': 'neighborhood',
#   'suggestedBounds': {'ne': {'lat': 43.6532000045, 'lng': -79.3792325748274},
#    'sw': {'lat': 43.644199995499996, 'lng': -79.39164742517261}},
#   'suggestedFilters': {'filters': [{'key': 'openNow', 'name': 'Open now'}],
#    'header': 'Tap to show:'},
#   'totalResults': 156}}

# %%
import numpy as np

# Set pandass display settings
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)



#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values



# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans
